# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./Palestine/data.csv')

# %%
df.head()
# Out:
#                                           name date_of_event   age  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
#
#    citizenship     event_location event_location_district  \
# 0  Palestinian     Nur Shams R.C.                 Tulkarm
# 1  Palestinian     Nur Shams R.C.                 Tulkarm
# 2  Palestinian           Kfar Dan                   Jenin
# 3  Palestinian  'Aqbat Jaber R.C.                 Jericho
# 4  Palestinian         Jenin R.C.                   Jenin
#
#   event_location_region date_of_death gender took_part_in_the_hostilities  \
# 0             West Bank    2023-09-24      M                          NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11124 entries, 0 to 11123
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   name                          11124 non-null  object
#  1   date_of_event                 11124 non-null  object
#  2   age                           10995 non-null  float64
#  3   citizenship                   11124 non-null  object
#  4   event_location                11124 non-null  object
#  5   event_location_district       11124 non-null  object
#  6   event_location_region         11124 non-null  object
#  7   date_of_death                 11124 non-null  object
#  8   gender                        11104 non-null  object
#  9   took_part_in_the_hostilities  9694 non-null   object
#  10  place_of_residence            11056 non-null  object
#  11  place_of_residence_district   11056 non-null  object
# ...

# %%
df.shape
# Out:
# (11124, 16)

# %%
df.describe()
# Out:
#                 age
# count  10995.000000
# mean      26.745703
# std       13.780548
# min        1.000000
# 25%       19.000000
# 50%       23.000000
# 75%       31.000000
# max      112.000000

# %%
sns.countplot(x='citizenship',data=df)
# Out:
# <Axes: xlabel='citizenship', ylabel='count'>

# %%
fig = plt.figure(figsize=(30,8))
sns.countplot(x='event_location_district',data=df)
# Out:
# <Axes: xlabel='event_location_district', ylabel='count'>

# %%
sns.countplot(x='gender',data=df,hue='citizenship')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
fig = plt.figure(figsize=(30,8))
sns.countplot(x='type_of_injury',data=df, hue='citizenship')
# Out:
# <Axes: xlabel='type_of_injury', ylabel='count'>

# %%
sns.displot(x=df['age'])
# Out:
# C:\Users\SAIFULLAH KHAN\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x='citizenship',y='age',data=df)
# Out:
# <Axes: xlabel='citizenship', ylabel='age'>

# %%
df[df['age']<5]
# Out:
#                                        name date_of_event  age  citizenship  \
# 83          Muhammad Haitham Ibrahim Tamimi    2023-06-01  2.0  Palestinian
# 124           Hajar Khalil Salah al-Bahtini    2023-05-09  4.0  Palestinian
# 340             Jamil Najm a-Din Jamil Nijm    2022-08-07  3.0  Palestinian
# 539    Adam 'Izat Mu'in al-Kolak (al-Qolaq)    2021-05-16  3.0  Palestinian
# 585           Yihya Riyad Hassan Ishkuntana    2021-05-16  4.0  Palestinian
# ...                                     ...           ...  ...          ...
# 10577                            Oriah Ilan    2002-03-02  1.0      Israeli
# 10582                          Liran Nehmad    2002-03-02  3.0      Israeli
# 10787                     Burhan al-Haymuni    2001-12-10  3.0  Palestinian
# 11005                Hemda Schijveschuurder    2001-08-09  2.0      Israeli
# 11010      Avraham Yitzhak Schijveschuurder    2001-08-09  4.0      Israeli
#
# ...

# %%
sns.countplot(x='killed_by',data=df)
# Out:
# <Axes: xlabel='killed_by', ylabel='count'>

# %%
df[df['citizenship']=='Israeli']
# Out:
#                          name date_of_event   age citizenship event_location  \
# 16            Batsheva Nagari    2023-08-21  40.0     Israeli     Beit Hagai
# 17                  Aviad Nir    2023-08-19  28.0     Israeli        Huwarah
# 18        Shai Silas Nigerker    2023-08-19  60.0     Israeli        Huwarah
# 29                  Chen Amir    2023-08-05  42.0     Israeli  Tel Aviv-Yafo
# 66     Nachman Shmuel Mordoff    2023-06-20  17.0     Israeli            Eli
# ...                       ...           ...   ...         ...            ...
# 11117           Amos Machlouf    2000-10-28  30.0     Israeli      Beit Jala
# 11118          Marik Gavrilov    2000-10-27  25.0     Israeli       Ramallah
# 11119        Binyamin Herling    2000-10-19  64.0     Israeli         Nablus
# 11121        Hillel Lieberman    2000-10-07  36.0     Israeli         Nablus
# 11123       Wichlav Zalsevsky    2000-10-02  24.0     Israeli          Masha
#
# ...
